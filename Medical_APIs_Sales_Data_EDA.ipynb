# %% [markdown]
# <a href="https://colab.research.google.com/github/faizzpersonal/Medical-APIs-Sale-Analysis/blob/main/Medical_APIs_Sales_Data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
CustomerTable=pd.read_csv('/content/CustomerTable.csv')

# %%
DrugLookup=pd.read_csv('/content/DrugLookup.csv')

# %%
FactTable=pd.read_csv('/content/FactTable.csv')

# %%
CustomerTable.head()
# Out:
#    CustomerID FirstName LastName  Age  Gender    Country   OtherCustomerInfo
# 0           1       Bob    Smith   76    Male  Australia      Frequent Buyer
# 1           2       Bob  Johnson   56    Male  Australia        New Customer
# 2           3       Bob    Smith   74  Female  Australia      Frequent Buyer
# 3           4     David    Jones   54    Male  Australia      Frequent Buyer
# 4           5      John  Johnson   51    Male  Australia  Preferred Customer

# %%
CustomerTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         200 non-null    int64
#  1   FirstName          200 non-null    object
#  2   LastName           200 non-null    object
#  3   Age                200 non-null    int64
#  4   Gender             200 non-null    object
#  5   Country            200 non-null    object
#  6   OtherCustomerInfo  200 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 11.1+ KB

# %% [markdown]
# We Need To Merge FirstName And LastName For Better Ananlysis

# %%
CustomerTable['FullName']=CustomerTable['FirstName']+" "+CustomerTable['LastName']

# %%
CustomerTable=CustomerTable.drop(['FirstName','LastName','OtherCustomerInfo'],axis=1)

# %%
CustomerTable.head()
# Out:
#    CustomerID  Age  Gender    Country      FullName
# 0           1   76    Male  Australia     Bob Smith
# 1           2   56    Male  Australia   Bob Johnson
# 2           3   74  Female  Australia     Bob Smith
# 3           4   54    Male  Australia   David Jones
# 4           5   51    Male  Australia  John Johnson

# %% [markdown]
# We Need To Create Age Bin For Better Analysis

# %%
bins = [0, 20, 30, 40, 50, 100]
labels = ['0-20', '21-30', '31-40', '41-50', '50+']

# Create age bins
CustomerTable['Age Bin'] = pd.cut(CustomerTable['Age'], bins=bins, labels=labels, right=False)

# %%
CustomerTable.tail()
# Out:
#      CustomerID  Age  Gender         Country       FullName Age Bin
# 195         196   42   Other  United Kingdom     John Smith   41-50
# 196         197   32    Male  United Kingdom   John Johnson   31-40
# 197         198   39    Male          Canada     John Jones   31-40
# 198         199   60  Female       Australia      Bob Jones     50+
# 199         200   54  Female  United Kingdom  Jane Williams     50+

# %%
DrugLookup.head()
# Out:
#    DrugID  RegulatoryComplianceID       DrugName  UnitSalesPrice  \
# 0       1                       1    Amoxicillin           74.73
# 1       2                       1      Ibuprofen          315.78
# 2       3                       2   Atorvastatin          165.93
# 3       4                       1  Levothyroxine          356.71
# 4       5                       1      Metformin           88.10
#
#    CostOfProduction                       Treats
# 0             56.01    Treatment for Amoxicillin
# 1             87.47      Treatment for Ibuprofen
# 2             70.64   Treatment for Atorvastatin
# 3             62.70  Treatment for Levothyroxine
# 4             40.00      Treatment for Metformin

# %%
DrugLookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DrugID                  40 non-null     int64
#  1   RegulatoryComplianceID  40 non-null     int64
#  2   DrugName                40 non-null     object
#  3   UnitSalesPrice          40 non-null     float64
#  4   CostOfProduction        40 non-null     float64
#  5   Treats                  40 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.0+ KB

# %%
DrugLookup=DrugLookup.drop('Treats',axis=1)

# %%
DrugLookup.head()
# Out:
#    DrugID  RegulatoryComplianceID       DrugName  UnitSalesPrice  \
# 0       1                       1    Amoxicillin           74.73
# 1       2                       1      Ibuprofen          315.78
# 2       3                       2   Atorvastatin          165.93
# 3       4                       1  Levothyroxine          356.71
# 4       5                       1      Metformin           88.10
#
#    CostOfProduction
# 0             56.01
# 1             87.47
# 2             70.64
# 3             62.70
# 4             40.00

# %%
FactTable.head()
# Out:
#    SaleID  DrugID  CustomerID  UnitsSold   SaleDate BuyerType
# 0       1      25         159        100   2/2/2023    Seller
# 1       2       8          64          1   2/2/2023      User
# 2       3      38         142          4  2/18/2023      User
# 3       4      36          84         66  9/15/2023    Seller
# 4       5      23         118          2  10/6/2023      User

# %%
FactTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16314 entries, 0 to 16313
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SaleID      16314 non-null  int64
#  1   DrugID      16314 non-null  int64
#  2   CustomerID  16314 non-null  int64
#  3   UnitsSold   16314 non-null  int64
#  4   SaleDate    16314 non-null  object
#  5   BuyerType   16314 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 764.8+ KB
